# %%
# %%js
# class FrogSpecies {
#     constructor(name, size, habitat, predators, diet, lifespan, toxicity, funFacts) {
#         this.name = name;
#         this.size = size;
#         this.habitat = habitat;
#         this.predators = predators;
#         this.diet = diet;
#         this.lifespan = lifespan;
#         this.toxicity = toxicity;
#         this.funFacts = funFacts;
#     }
#
#     print() {
#         console.log(`Species: ${this.name}`);
#         console.log(`Size: ${this.size}`);
#         console.log(`Habitat: ${this.habitat}`);
#         console.log(`Predators: ${this.predators}`);
#         console.log(`Diet: ${this.diet}`);
#         console.log(`Lifespan: ${this.lifespan}`);
#         console.log(`Toxicity: ${this.toxicity}`);
#         console.log(`Fun Facts: ${this.funFacts}`);
#         console.log('----------------------------------------');
#     }
# }
#
# // Create an array to store frog instances
# var frogSpeciesArray = [];
#
# // Function to add a new frog species to the array
# function addFrogSpecies(name, size, habitat, predators, diet, lifespan, toxicity, funFacts) {
#     var frog = new FrogSpecies(name, size, habitat, predators, diet, lifespan, toxicity, funFacts);
#     frogSpeciesArray.push(frog);
# }
#
# // Add frog species to the array
# addFrogSpecies(
#     "Sumaco Horned Frog (Hemiphractus proboscideus)",
#     "The Sumaco Horned Frog is medium-sized, typically reaching a size of around 1.5 to 2 inches (3.8 to 5 centimeters).",
#     "The Sumaco Horned Frog is native to the cloud forests of Ecuador in South America. It is found in the Sumaco Volcano area, which is its namesake.",
#     "Predators of the Sumaco Horned Frog may include snakes and certain birds that inhabit the same region.",
#     "Sumaco Horned Frogs primarily feed on insects and small invertebrates in their natural habitat.",
#     "The typical lifespan of the Sumaco Horned Frog in the wild is around 8 to 10 years.",
#     "The Sumaco Horned Frog is not considered highly poisonous or toxic. It does not possess the potent skin toxins seen in some other frog species.",
#     "The Sumaco Horned Frog gets its name from the distinctive bony horn-like protrusions above its eyes, which give it a unique appearance.These frogs have a cryptic coloration, often resembling moss or lichen, helping them blend into their forest environment.
# They are known for their unique reproductive behavior, with males guarding eggs and tadpoles, which they carry on their backs.
# This species is native to a specific and limited geographic range, making it an interesting subject of study and conservation concern."
# );
#
# addFrogSpecies(
#     "Dart Frog",
#     "Tiny",
#     "Central and South America",
#     "Snakes, birds",
#     "Ants, mites",
#     "3 years",
#     "Poisonous",
#     "Some species are used by indigenous people to poison their blowgun darts."
# );
#
# addFrogSpecies(
#     "Green Tree Frog (Litoria caerulea)",
#     "Small",
#     "Australia, New Guinea",
#     "Snakes, birds",
#     "Insects, small invertebrates",
#     "16 years",
#     "Not Poisonous",
#     "Known for their distinctive calls during mating season."
# );
#
# addFrogSpecies(
#     "Poison Dart Frog (Dendrobates tinctorius)",
#     "Small",
#     "Central and South America",
#     "Snakes, birds",
#     "Ants, termites",
#     "3-15 years",
#     "Highly Poisonous",
#     "Brightly colored; used by indigenous people to poison darts."
# );
#
# addFrogSpecies(
#     "Leopard Frog (Lithobates pipiens)",
#     "Medium",
#     "North America",
#     "Snakes, birds",
#     "Insects, small invertebrates",
#     "2-4 years",
#     "Mildly Toxic",
#     "Distinctive spots on their skin; good swimmers."
# );
#
# addFrogSpecies(
#     "Red-eyed Tree Frog (Agalychnis callidryas)",
#     "Small",
#     "Central America",
#     "Snakes, birds",
#     "Insects, small invertebrates",
#     "5 years",
#     "Not Poisonous",
#     "Large, vibrant red eyes; nocturnal."
# );
#
# addFrogSpecies(
#     "African Bullfrog (Pyxicephalus adspersus)",
#     "Large",
#     "Sub-Saharan Africa",
#     "Snakes, birds",
#     "Insects, small vertebrates",
#     "15 years",
#     "Mildly Toxic",
#     "Large and aggressive; males protect tadpoles in their mouths."
# );
#
# addFrogSpecies(
#     "Wood Frog (Lithobates sylvaticus)",
#     "Small",
#     "North America",
#     "Snakes, birds",
#     "Insects, small invertebrates",
#     "2-3 years",
#     "Not Poisonous",
#     "Can survive freezing during hibernation."
# );
#
# addFrogSpecies(
#     "Golden Poison Dart Frog (Phyllobates terribilis)",
#     "Small",
#     "Central and South America",
#     "Snakes, birds",
#     "Ants, termites",
#     "Up to 15 years",
#     "Highly Poisonous",
#     "One of the most toxic animals on Earth."
# );
#
# addFrogSpecies(
#     "Budgett's Frog (Paraguay horned frog)",
#     "Large",
#     "South America",
#     "Snakes, birds",
#     "Insects, small vertebrates",
#     "10 years",
#     "Mildly Toxic",
#     "Wide mouth, flattened body; resembles a toad with a 'grin.'"
# );
#
# addFrogSpecies(
#     "Amazon Milk Frog (Trachycephalus resinifictrix)",
#     "Medium",
#     "South America",
#     "Snakes, birds",
#     "Insects, small invertebrates",
#     "10 years",
#     "Not Poisonous",
#     "Excretes a milky secretion when threatened."
# );
#
# addFrogSpecies(
#     "Malayan Horned Frog (Megophrys nasuta)",
#     "Medium",
#     "Southeast Asia",
#     "Snakes, birds",
#     "Insects, small vertebrates",
#     "Up to 9 years",
#     "Not Poisonous",
#     "Horned appearance on the eyelids and nose."
# );
#
# // Add more frog species to the array...
#
# // Loop through the array and print details for each frog
# for (var frog of frogSpeciesArray) {
#     frog.print();
# }
