# %%
# %%js
# class Poison {
#     constructor(name, toxicity, breed, sound, lifespan, predators, diet, size) {
#         this.name = name;
#         this.toxicity = toxicity;
#         this.breed = breed;
#         this.sound = sound;
#         this.lifespan = lifespan;
#         this.predators = predators;
#         this.diet = diet;
#         this.size = size;
#     }
#
#     print() {
#         console.log(this.name, this.toxicity, this.breed, this.getSound(), this.lifespan, this.predators, this.diet, this.size);
#     }
#
#     getSound() {
#         return this.sound;
#         // Additional code to make sound goes here
#     }
# }
#
# class Bull extends Poison {
#     constructor(name, toxicity, breed, sound, lifespan, predators, diet, size) {
#         super(name, toxicity, breed, sound, lifespan, predators, diet, size);
#     }
#
#     // No need to override getSound if it behaves the same way
# }
#
# class Glass extends Poison {
#     constructor(name, toxicity, breed, sound, lifespan, predators, diet, size) {
#         super(name, toxicity, breed, sound, lifespan, predators, diet, size);
#     }
#
#     // No need to override getSound if it behaves the same way
# }
#
# class Greenings extends Poison {
#     constructor(name, toxicity, breed, sound, lifespan, predators, diet, size) {
#         super(name, toxicity, breed, sound, lifespan, predators, diet, size);
#     }
#
#     // No need to override getSound if it behaves the same way
# }
#
# class Wood extends Poison {
#     constructor(name, toxicity, breed, sound, lifespan, predators, diet, size) {
#         super(name, toxicity, breed, sound, lifespan, predators, diet, size);
#     }
#
#     // No need to override getSound if it behaves the same way
# }
# var poisonName = "Jack";
# var poisonToxicity = "Poisonous";
# var poisonBreed = "Poison-Dart Frog";
# var poisonSound = "ribbit";
# var poisonLifespan = "15 years";
# var poisonPredators = "snakes and birds";
# var poisonDiet = "insects like ants and termites";
# var poisonSize = "2.5 inches";
# var poison = new Poison(poisonName, poisonToxicity, poisonBreed, poisonSound, poisonLifespan, poisonPredators, poisonDiet, poisonSize);
#
# var bullName = "Michael";
# var bullToxicity = "Poisonous";
# var bullBreed = "Bull Frog";
# var bullSound = "ributt";
# var bullLifespan = "10 years";
# var bullPredators = "Birds, racoons, snakes, and fish";
# var bullDiet = "insects, small fish, crustaceans, and small frogs";
# var bullSize = "6 inches";
# var bull = new Bull(bullName, bullToxicity, bullBreed, bullSound, bullLifespan, bullPredators, bullDiet, bullSize);
#
# var glassName = "John";
# var glassToxicity = "Not Poisonous";
# var glassBreed = "Glass Frog";
# var glassSound = "bribit";
# var glassLifespan = "14 years";
# var glassPredators ="birds, snakes, and large insects";
# var glassDiet = "small insects and inverterates ";
# var glassSize = "3 inches";
# var glass = new Glass(glassName, glassToxicity, glassBreed, glassSound, glassLifespan, glassPredators, glassDiet, glassSize);
#
# var greeningsName = "Green";
# var greeningsToxicity = "Poisonous";
# var greeningsBreed = "Greenings";
# var greeningsSound = "ribb";
# var greeningsLifespan = "16 years";
# var greeningsPredators = "birds, snakes, racoons, and larger amphibians";
# var greeningsDiet = "insects, spiders, and small invertebrates";
# var greeningsSize = "3.5 inches";
# var greenings = new Greenings(greeningsName, greeningsToxicity, greeningsBreed, greeningsSound, greeningsLifespan, greeningsPredators, greeningsDiet, greeningsSize);
#
# var woodName = "Woody";
# var woodToxicity = "Poisonous";
# var woodBreed = "wood";
# var woodSound = "ribby";
# var woodLifespan = "3 years";
# var woodPredators = "birds, snakes, mamals, and larger amphibians";
# var woodDiet = "insects, spiders, and small invertebrates";
# var woodSize = "2.2 inches";
# var wood = new Wood(woodName, woodToxicity, woodBreed, woodSound, woodLifespan, woodPredators, wood,Diet, woodSize);
#
# var animals = [poison, bull, glass, greenings, wood];
# for (var animal of animals) {
#     animal.print();
# }
