# %%
# %%js
# addFrogSpecies(
#     "White's Tree Frog",
#     "5.5 inches",
#     "North and East Australia",
#     "Snakes, birds, mammals like raccoons, larger insects, and larger amphibians",
#     "insects like crickets, cockroaches, moths, and beetles.",
#     "Up to 16 years",
#     "Not Poisonous",
#     "They are often referred to as dumpy tree frogs due to their plump appearance."
# );
